# %% [markdown]
# # 1. Project Overview (comeback to outline the steps you'll follow in the notebook)

# %% [markdown]
# This project aims to build a data-driven matchmaking system that enhances compatibility in online dating by leveraging user demographics, lifestyle traits, and personal essays. Using the OKCupid Profiles Dataset from Kaggle, the system employs BERT embeddings for text analysis and feature importance for structured data to generate personalized, content-based recommendations. Unlike modern dating apps that rely on swiping behavior, this approach prioritizes compatibility over interaction history, making it ideal for a blind dating experience where personality and shared values take center stage.

# %% [markdown]
# # 2. Import Libraries

# %% [markdown]
# This section focuses on importing the OKCupid dataset from Kaggle, looking at the comprehensive overview and descriptive statistics. I will then look at the amount of data missing.

# %%
import kagglehub
import pandas as pd
import re

# !pip install -U sentence-transformers
from sentence_transformers import SentenceTransformer

# !pip install swifter
import swifter

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from datetime import datetime, timedelta
from nltk.corpus import stopwords
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from nltk.stem import WordNetLemmatizer
from textblob import Word
# !pip install pyspellchecker
from spellchecker import SpellChecker
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.48.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.5.1+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Requirement already satisfied: swifter in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (2.2.2)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.11/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2024.10.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.6.1)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.1.16)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.10.0->swifter) (17.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.17.0)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.11/dist-packages (0.8.2)

# %% [markdown]
# # 3. Load and Explore Data

# %%
path = kagglehub.dataset_download("andrewmvd/okcupid-profiles")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Path to dataset files: /root/.cache/kagglehub/datasets/andrewmvd/okcupid-profiles/versions/1

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/andrewmvd/okcupid-profiles/versions/1/okcupid_profiles.csv', sep=",",header=0)
df.sample(5)
# Out:
#        age          status sex orientation body_type             diet  \
# 14923   28  seeing someone   f         gay       NaN       vegetarian
# 11084   24          single   m    straight   average  mostly anything
# 26526   27  seeing someone   f    straight      thin              NaN
# 34561   41          single   f    straight   average  mostly anything
# 50473   33          single   m    straight   average              NaN
#
#          drinks  drugs                          education  \
# 14923  socially  never  graduated from college/university
# 11084  socially  never     graduated from masters program
# 26526  socially  never  graduated from college/university
# 34561  socially  never                                NaN
# 50473  socially    NaN  graduated from college/university
#
#                     ethnicity  ...  \
# 14923                     NaN  ...
# 11084                   asian  ...
# 26526            asian, white  ...
# 34561  native american, white  ...
# 50473  native american, white  ...
#
#                                                   essay0  \
# 14923  i am a secret softy. i wear an armor of steel ...
# 11084  grew up in northern california and went to sch...
# 26526  i feel like i'm going against cultural and soc...
# 34561  i'm so much better about answering direct ques...
# 50473  i am a damn sexy, fun loving, geek. i watch do...
#
#                                                   essay1  \
# 14923  figuring out what makes me happy.  oh, and wor...
# 11084  graduated from ucsd with a ms in biology. i cu...
# 26526  at a crossroads in sf, deciding which directio...
# 34561  i'm currently managing an independent bookstor...
# 50473  living it the best i can and making do with wh...
#
#                                                   essay2  \
# 14923  blurring the lines of "appropriate" conversati...
# 11084  picking up new sports and hobbies. i've been s...
# 26526  adapting to new situations. forcing myself out...
# 34561  making people feel better. seriously. that's m...
# 50473  computers i have been tearing them down since ...
#
#                                                   essay3  \
# 14923      my tie-clip? or suspenders? maybe my tattoos?
# 11084  i've heard people describe me as quite at firs...
# 26526  some have said the voice, some say the smile, ...
# 34561           i have no idea, you'll have to ask them.
# 50473  i asked a friend to answer this she said my ey...
#
#                                                   essay4  \
# 14923  no one belongs here more than you, the red ten...
# 11084  the hunger games (addicting), the princess bri...
# 26526  two books that changed my life: the ecology of...
# 34561  books: maia, richard adams; the secret history...
# 50473  i could fill up 2 pages answering this questio...
#
#                                                   essay5  \
# 14923                                                NaN
# 11084   close friends family internet food trucks iphone
# 26526  1) cheesy sentimentality. 2) awesome people. 3...
# 34561  -my girls -amazing food -my ipod -compassion -...
# 50473  1. family, always comes first and i wouldn't b...
#
#                                                   essay6  \
# 14923                                                NaN
# 11084  restaurants i want to go to, cities i want to ...
# 26526  how i can find a calm center when everything c...
# 34561  why people do what they do. why i do what i do...
# 50473  how epic the new elder scrolls mmo will be, an...
#
#                                                   essay7  \
# 14923  some things i'd enjoy doing: (specifically, th...
# 11084  it depends, sometimes i'll be hanging out with...
# 26526  brushing my teeth. actually, that's every nigh...
# 34561  half the time, i'm with kids, which means movi...
# 50473  either home gaming and listening to music or o...
#
#                                                   essay8  \
# 14923                                                NaN
# 11084  i like visiting home decor stores... like west...
# 26526  i'm a pretty strong infj (myers-briggs). but i...
# 34561                            naruto has made me cry.
# 50473  every year for the last 6 years i have volunte...
#
#                                                   essay9
# 14923  you want to go on adventures or have deep/triv...
# 11084                    if anything here interests you!
# 26526  all of the following are positive, women and m...
# 34561  -you're not just looking for a booty call. -yo...
# 50473                                                NaN
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB

# %%
df.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
# Calculate the percentage of missing values for each column
missing_summary = df.isnull().agg(['sum', 'mean']).T

# Rename columns for clarity
missing_summary.columns = ['# Missing Values', '% Missing']

# Format percentage as a string with two decimal places
missing_summary['% Missing'] = (missing_summary['% Missing'] * 100).apply(lambda x: f"{x:.2f}%")

# Display the result
print(missing_summary)
# Out:
#              # Missing Values % Missing
# age                       0.0     0.00%
# status                    0.0     0.00%
# sex                       0.0     0.00%
# orientation               0.0     0.00%
# body_type              5296.0     8.83%
# diet                  24395.0    40.69%
# drinks                 2985.0     4.98%
# drugs                 14080.0    23.49%
# education              6628.0    11.06%
# ethnicity              5680.0     9.48%
# height                    3.0     0.01%
# income                    0.0     0.00%
# job                    8198.0    13.68%
# last_online               0.0     0.00%
# location                  0.0     0.00%
# offspring             35561.0    59.32%
# pets                  19921.0    33.23%
# religion              20226.0    33.74%
# sign                  11056.0    18.44%
# smokes                 5512.0     9.19%
# speaks                   50.0     0.08%
# essay0                 5488.0     9.15%
# essay1                 7572.0    12.63%
# essay2                 9638.0    16.08%
# essay3                11476.0    19.14%
# essay4                10537.0    17.58%
# essay5                10850.0    18.10%
# essay6                13771.0    22.97%
# essay7                12451.0    20.77%
# essay8                19225.0    32.07%
# essay9                12603.0    21.02%

# %% [markdown]
# The sample showed me rows with a lot of missing information. I want to take a deeper look to see if it is worth dropping rows with more than half of the features missing as there is no way to fill in the information lost.

# %%
# Count the number of NaN values per row
nan_counts_per_row = df.isnull().sum(axis=1)

# Define a threshold (e.g., more than half the columns)
threshold = df.shape[1] // 2

# Count the rows with NaN values exceeding the threshold
rows_above_threshold = (nan_counts_per_row > threshold).sum()

# Display the count
print(f"Number of rows with NaNs exceeding the threshold of {threshold}: {rows_above_threshold}")

percent_missing = (rows_above_threshold / len(df)) * 100
print(f"Percentage of rows with NaNs exceeding the threshold of {threshold}: {percent_missing:.2f}%")
# Out:
# Number of rows with NaNs exceeding the threshold of 15: 931
# Percentage of rows with NaNs exceeding the threshold of 15: 1.55%

# %% [markdown]
# I have decided to drop the income, body_type, sign, and last_online columns as they don't hold a significant importance in matchmaking.

# %%
df.drop(columns=['income', 'body_type', 'sign', 'last_online'], inplace=True)

# %% [markdown]
# #4. Data Preprocessing

# %% [markdown]
# 1.45% of the data contains rows with more than 15 features missing. I will remove them as dropping them will not impact the dataset.

# %%
df = df[nan_counts_per_row <= threshold]

# %%
df.sample(10)
# Out:
#        age          status sex orientation               diet      drinks  \
# 56611   31          single   f    straight  strictly anything      rarely
# 52802   56          single   m    straight                NaN    socially
# 15938   57          single   m    straight                NaN      rarely
# 4195    19          single   m    straight    mostly anything  not at all
# 45154   26  seeing someone   m    bisexual    mostly anything    socially
# 48684   28          single   m    straight                NaN    socially
# 3078    22          single   m         gay              vegan    socially
# 37349   28          single   f    straight           anything    socially
# 24038   40          single   f    straight                NaN    socially
# 45681   29          single   m    straight                NaN    socially
#
#        drugs                          education         ethnicity  height  \
# 56611  never     graduated from masters program  hispanic / latin    63.0
# 52802    NaN  dropped out of college/university             white    71.0
# 15938    NaN     graduated from masters program             white    71.0
# 4195   never             working on high school  hispanic / latin    72.0
# 45154  never              working on space camp               NaN    72.0
# 48684  never         working on masters program             asian    73.0
# 3078     NaN  graduated from college/university            indian    74.0
# 37349    NaN            working on ph.d program             white    63.0
# 24038  never     graduated from masters program             white    68.0
# 45681  never  dropped out of college/university             white    70.0
#
#        ...                                             essay0  \
# 56611  ...                                                NaN
# 52802  ...  i drive around the bay area on weekends, looki...
# 15938  ...                                                NaN
# 4195   ...  i'm 18 years and love to enjoy life. i like to...
# 45154  ...  i'm just me. i don't really know how to explai...
# 48684  ...  well, in a nut-shell i consider myself and eas...
# 3078   ...  just graduated from the institution, now spend...
# 37349  ...  seriously i just can't summarize myself! i thi...
# 24038  ...  i am an (allegedly) good looking, successful, ...
# 45681  ...                                                NaN
#
#                                                   essay1  \
# 56611                                                NaN
# 52802  trying to build a company that's gonna change ...
# 15938                                                NaN
# 4195   i am a student that is trying to finish colleg...
# 45154  i'm currently working as a computer technician...
# 48684  finishing up my final year in grad school and ...
# 3078   finding beauty in post-graduation nothingness....
# 37349  for now... i am trying to find my balance betw...
# 24038  i have both achieved the improbable and failed...
# 45681                                                NaN
#
#                                                   essay2  \
# 56611                                                NaN
# 52802  solving problems that require you to hold seve...
# 15938                                                NaN
# 4195   baseball, making people laugh, drinking coffee...
# 45154  martial arts (the ones i've already learned), ...
# 48684  board games, karaoke, and eating a lot. if you...
# 3078   recognizing dystopia, singing the destiny's ch...
# 37349  - laughing! laughing everyday should be a requ...
# 24038  intuitive driving and polarizing. but i am a l...
# 45681                                                NaN
#
#                                                   essay3  \
# 56611                                                NaN
# 52802                            my striking good looks.
# 15938                                                NaN
# 4195   they notice my hair because when its loose its...
# 45154  my nerd powers!! i don't wear them physically,...
# 48684       hmmm...dunno but i hope it's something good.
# 3078                                       "you're tall"
# 37349  depends on the people i guess: i prefer those ...
# 24038   how would i know. remember, i am a narcissist;-)
# 45681                                                NaN
#
#                                                   essay4  \
# 56611  i love to eat i love sushi, thai, mexican stea...
# 52802  moby dick, duck soup, iko iko, an italian sub ...
# 15938                                                NaN
# 4195   my favorite books are the harry potter series(...
# 45154  i'm a big fan of shakespeare and don't try to ...
# 48684  books: the walking drunk, trainspotting, cat's...
# 3078   books: the god of small things, black skin whi...
# 37349  books: authors like milan kundera, katherine p...
# 24038  i read kierkegaard and listen to eminem (admit...
# 45681                                                NaN
#
#                                                   essay5  \
# 56611                                                NaN
# 52802     food, shelter, clothing, sleep, nature, people
# 15938                                                NaN
# 4195   my family. my iphone a daily shower my basebal...
# 45154  a computer, a job, my family, a well crafted w...
# 48684  1. whole milk (it really is the best) 2. the d...
# 3078   baduizm, borderlands, my bike, a pencil and pa...
# 37349  1/ music, music, and music 2/ friends 3/ trave...
# 24038  knowledge. freedom. laughter. love. inspiratio...
# 45681                                                NaN
#
#                                                   essay6  \
# 56611                      my family, friends, my future
# 52802  the information ecology. ... and what's for di...
# 15938                                                NaN
# 4195   life. its fricken crazy how we all came to be ...
# 45154  why is my astrological description is complete...
# 48684                                                NaN
# 3078   -my love for arundhati roy -projects i want to...
# 37349  well... i do think a lot... human beings fasci...
# 24038  - if most people really are that spiritually u...
# 45681                        everything. i over analyze.
#
#                                                   essay7  \
# 56611                              in the movie theater.
# 52802                        unwinding from a busy week.
# 15938                                                NaN
# 4195   out with my friends or drag racing. sometimes ...
# 45154  doing whatever the hell i please!! i never bog...
# 48684  usually out and about around inner richmond of...
# 3078                                                 NaN
# 37349  as many people say i don't have a typical frid...
# 24038  working out. cooking dinner with friends. at t...
# 45681                                                NaN
#
#                                                   essay8  \
# 56611                                                NaN
# 52802                    i'm wearing a blue shirt, today
# 15938                                                NaN
# 4195   i'm willing to admit that my first girlfriend ...
# 45154  ..hmm... i will admit to sleeping bare ass! if...
# 48684  i have quite a few geeky obsessions. i've gone...
# 3078                                                 NaN
# 37349                     definitely not on the internet
# 24038  is the fact that i am desperately trying to ma...
# 45681                                                NaN
#
#                                                   essay9
# 56611  you want to have a new friend, have fun or a l...
# 52802                            you feel like chatting.
# 15938                                                NaN
# 4195   your interested in meeting me or just want to ...
# 45154  you are sane, intellegent and interested. all ...
# 48684                                                NaN
# 3078   you are interested in the best vegan peanut bu...
# 37349                                  you got inspired!
# 24038  you can read and comprehend my self summary wi...
# 45681                  you would like to know me better.
#
# [10 rows x 27 columns]

# %% [markdown]
# ## 4.1 Cleaning Numerical Columns

# %% [markdown]
# The numerical columns include age, height, and income.

# %% [markdown]
# ### Age Column

# %%
print("Age Min", df['age'].min())
print("Age Max", df['age'].max())
# Out:
# Age Min 18
# Age Max 109

# %% [markdown]
# **Handling Outliers in Age Column**
# - The minimum age is acceptable and doesn't require changes.
# - The maximum age needs to be addressed as it exceeds realistic limits.
# - Further steps:
#   1. Investigate rows with ages over 100.
#   2. Determine whether to remove or impute those values.

# %%
df['age'].value_counts().sort_index()
# Out:
# age
# 18      298
# 19      582
# 20      925
# 21     1246
# 22     1895
# 23     2546
# 24     3189
# 25     3497
# 26     3663
# 27     3625
# 28     3531
# 29     3258
# 30     3105
# 31     2689
# 32     2547
# 33     2177
# 34     1874
# 35     1728
# 36     1564
# 37     1398
# 38     1308
# 39     1154
# 40     1014
# 41      971
# 42     1054
# 43      842
# 44      698
# 45      639
# 46      571
# 47      525
# 48      474
# 49      454
# 50      433
# 51      343
# 52      341
# 53      245
# 54      265
# 55      263
# 56      264
# 57      255
# 58      196
# 59      218
# 60      194
# 61      175
# 62      166
# 63      137
# 64      110
# 65      108
# 66      105
# 67       66
# 68       59
# 69       30
# 109       1
# Name: count, dtype: int64

# %% [markdown]
# Looked closer at ages 109, and 110 and decided to drop them due to a lot of missing data that cannot be filled in.

# %%
df[(df['age'] == 109) | (df['age'] == 110)]
# Out:
#        age     status sex orientation          diet drinks  drugs  \
# 25324  109  available   m    straight  mostly other    NaN  never
#
#                         education ethnicity  height  ... essay0 essay1 essay2  \
# 25324  working on masters program       NaN    95.0  ...    NaN    NaN    NaN
#
#         essay3 essay4 essay5 essay6 essay7 essay8 essay9
# 25324  nothing    NaN    NaN    NaN    NaN    NaN    NaN
#
# [1 rows x 27 columns]

# %%
# filtering the data to no longer include ages 109 and 110

df = df[(df['age'] != 109) & (df['age'] != 110)]

# verifying the changes
df['age'].value_counts().sort_index()
# Out:
# age
# 18     298
# 19     582
# 20     925
# 21    1246
# 22    1895
# 23    2546
# 24    3189
# 25    3497
# 26    3663
# 27    3625
# 28    3531
# 29    3258
# 30    3105
# 31    2689
# 32    2547
# 33    2177
# 34    1874
# 35    1728
# 36    1564
# 37    1398
# 38    1308
# 39    1154
# 40    1014
# 41     971
# 42    1054
# 43     842
# 44     698
# 45     639
# 46     571
# 47     525
# 48     474
# 49     454
# 50     433
# 51     343
# 52     341
# 53     245
# 54     265
# 55     263
# 56     264
# 57     255
# 58     196
# 59     218
# 60     194
# 61     175
# 62     166
# 63     137
# 64     110
# 65     108
# 66     105
# 67      66
# 68      59
# 69      30
# Name: count, dtype: int64

# %% [markdown]
# The `age` column does not have any missing values, so we will move on to the `height` column.

# %% [markdown]
# ### Height Column

# %%
print("Min Height:",df['height'].min())
print("Max Height:",df['height'].max())
# Out:
# Min Height: 1.0
# Max Height: 95.0

# %%
df['height'].value_counts().sort_index()
# Out:
# height
# 1.0        1
# 3.0        1
# 4.0        1
# 6.0        1
# 8.0        1
# 9.0        1
# 26.0       1
# 36.0       9
# 37.0       2
# 42.0       1
# 43.0       2
# 47.0       1
# 48.0       1
# 49.0       1
# 50.0       2
# 51.0       1
# 52.0       1
# 53.0       5
# 54.0       3
# 55.0       6
# 56.0       8
# 57.0      17
# 58.0      52
# 59.0     211
# 60.0     775
# 61.0    1072
# 62.0    2217
# 63.0    2736
# 64.0    3822
# 65.0    3742
# 66.0    4696
# 67.0    5269
# 68.0    5382
# 69.0    5095
# 70.0    5976
# 71.0    4731
# 72.0    5211
# 73.0    2764
# 74.0    2509
# 75.0    1353
# 76.0     775
# 77.0     275
# 78.0     128
# 79.0      56
# 80.0      27
# 81.0      10
# 82.0      10
# 83.0      11
# 84.0       8
# 85.0       1
# 86.0       1
# 87.0       1
# 88.0       2
# 90.0       1
# 91.0       3
# 92.0       1
# 93.0       1
# 94.0       3
# 95.0      19
# Name: count, dtype: int64

# %% [markdown]
# There is no information on the unit for height. In this case, it makes sense to assume the height is in inches. I will filter out anomalies and the lowest recorded height will be 4'9" (59 inches) to 6'6" (80 inches).

# %%
df = df[(df['height'] >= 59) & (df['height'] <= 80)]

# %%
print("Min Height:",df['height'].min())
print("Max Height:",df['height'].max())
# Out:
# Min Height: 59.0
# Max Height: 80.0

# %%
df.sample(2)
# Out:
#        age  status sex orientation             diet    drinks      drugs  \
# 33484   25  single   f    straight         anything  socially      never
# 30693   28  single   m    straight  mostly anything  socially  sometimes
#
#                                education ethnicity  height  ...  \
# 33484  graduated from college/university     white    65.0  ...
# 30693  graduated from college/university     black    67.0  ...
#
#                                                   essay0  \
# 33484  hello everybody, im looking for some nice, fri...
# 30693  i recently moved to san francisco from dc and ...
#
#                                                   essay1  \
# 33484                                                NaN
# 30693  maintaining and progressing a professional car...
#
#                           essay2  \
# 33484                        NaN
# 30693  being a complete mystery.
#
#                                                   essay3  \
# 33484              happy, likes to party and to have fun
# 30693  physically, eyes or smile i suppose. i'm more ...
#
#                                                   essay4  \
# 33484                                  horror and comedy
# 30693  i wish i had more time to read fiction these d...
#
#                                               essay5  \
# 33484  .... my friends, sleeping,dancing,uuhhmmm....
# 30693                                            NaN
#
#                                   essay6  \
# 33484                                NaN
# 30693  ideas for screenplays. food. sex.
#
#                                                  essay7  \
# 33484                                               NaN
# 30693  relaxing at home after a typical long work week.
#
#                                                   essay8  \
# 33484                                                NaN
# 30693  you should be highly skeptical of anyone's ans...
#
#                                                   essay9
# 33484  you dont just wanna have sex..... if you repla...
# 30693  i'm not really the type to place conditions on...
#
# [2 rows x 27 columns]

# %% [markdown]
# The height column has 3 missing values, therefore I will drop it as there is no way to fill in the height with accuracy.

# %%
df.dropna(subset=['height'], inplace=True)

# %% [markdown]
# ## 4.2 Cleaning Categorical Columns

# %% [markdown]
# Categorical columns include demographics, interests, and lifestyle choices as well as 10 "essays" which are just answers to dating prompts.

# %% [markdown]
# ### Status

# %% [markdown]
# The status column has no missing values, therefore cleaning it will be simple.

# %%
# checking that the values in status are standardized
df['status'].value_counts()
# Out:
# status
# single            54642
# seeing someone     2032
# available          1842
# married             298
# unknown               8
# Name: count, dtype: int64

# %% [markdown]
# `single` has the most values followed by `seeing someone`. `available` and single can be merged together since there is overlap.

# %%
df['status'] = df['status'].replace({'single': 'single', 'available': 'single'})

print(df['status'].value_counts())
# Out:
# status
# single            56484
# seeing someone     2032
# married             298
# unknown               8
# Name: count, dtype: int64

# %% [markdown]
# ### Sex

# %%
# checking for missing values as well as making sure everything is standardized.
df['sex'].value_counts()
# Out:
# sex
# m    35091
# f    23731
# Name: count, dtype: int64

# %% [markdown]
# ### Orientation

# %%
df['orientation'].value_counts()
# Out:
# orientation
# straight    50613
# gay          5495
# bisexual     2714
# Name: count, dtype: int64

# %% [markdown]
# ### Diet
#
# Diet has 24395 missing values which affects 40.9% of the data. Let's take a look.

# %%
df['diet'].value_counts()
# Out:
# diet
# mostly anything        16493
# anything                6128
# strictly anything       5088
# mostly vegetarian       3434
# mostly other            1000
# strictly vegetarian      869
# vegetarian               662
# strictly other           444
# mostly vegan             337
# other                    328
# strictly vegan           228
# vegan                    136
# mostly kosher             85
# mostly halal              47
# strictly halal            18
# strictly kosher           18
# halal                     11
# kosher                    10
# Name: count, dtype: int64

# %%
df['diet'].sample(10)
# Out:
# 32468      mostly vegetarian
# 35866                    NaN
# 8234     strictly vegetarian
# 48581        mostly anything
# 58409                    NaN
# 9002         mostly anything
# 32175                    NaN
# 49627                    NaN
# 11568        mostly anything
# 6634                     NaN
# Name: diet, dtype: object

# %%
diet_mapping = {
    'anything': 'anything',
    'mostly anything': 'anything',
    'strictly anything': 'anything',
    'vegetarian': 'vegetarian',
    'mostly vegetarian': 'vegetarian',
    'strictly vegetarian': 'vegetarian',
    'vegan': 'vegan',
    'mostly vegan': 'vegan',
    'strictly vegan': 'vegan',
    'other': 'other',
    'mostly other': 'other',
    'strictly other': 'other',
    'kosher': 'kosher',
    'mostly kosher': 'kosher',
    'strictly kosher': 'kosher',
    'halal': 'halal',
    'mostly halal': 'halal',
    'strictly halal': 'halal'
}

df['diet'] = df['diet'].map(diet_mapping).fillna('unknown')

# %%
df['diet'].value_counts()
# Out:
# diet
# anything      27709
# unknown       23486
# vegetarian     4965
# other          1772
# vegan           701
# kosher          113
# halal            76
# Name: count, dtype: int64

# %%
df['diet'].sample(5)
# Out:
# 28464       unknown
# 14245    vegetarian
# 22219      anything
# 1682        unknown
# 33599       unknown
# Name: diet, dtype: object

# %% [markdown]
# ### Drinks/Drugs/Smoke
#
# The `drinks` column has 2,985 missing values which represents 4.98% of the data.
# `drugs` has 14,080 missing values which represents 23.49% of data.
# `smokes` has 5,512 missing values which represents 9.19% of data.

# %%
df['drinks'].value_counts()
# Out:
# drinks
# socially       41376
# rarely          5901
# often           5104
# not at all      3226
# very often       457
# desperately      312
# Name: count, dtype: int64

# %%
drinks_mapping = {
    'socially': 'socially',
    'rarely': 'rarely/not at all',
    'not at all': 'rarely/not at all',
    'often': 'often',
    'very often': 'often',
    'desperately': 'often'
}

df['drinks'] = df['drinks'].map(drinks_mapping).fillna('unknown')

print(df['drinks'].value_counts())
# Out:
# drinks
# socially             41376
# rarely/not at all     9127
# often                 5873
# unknown               2446
# Name: count, dtype: int64

# %%
# drugs
df['drugs'].value_counts()
# Out:
# drugs
# never        36972
# sometimes     7665
# often          392
# Name: count, dtype: int64

# %%
df['drugs'] = df['drugs'].fillna('unknown')
print(df['drugs'].isnull().sum())
# Out:
# 0

# %%
# smokes
df['smokes'].value_counts()
# Out:
# smokes
# no                43484
# sometimes          3739
# when drinking      3008
# yes                2196
# trying to quit     1471
# Name: count, dtype: int64

# %%
smokes_mapping = {
    'no': 'no',
    'sometimes': 'occasionally',
    'when drinking': 'occasionally',
    'yes': 'regularly',
    'trying to quit': 'trying to quit'
}

df['smokes'] = df['smokes'].map(smokes_mapping).fillna('unknown')

print(df['smokes'].value_counts())
# Out:
# smokes
# no                43484
# occasionally       6747
# unknown            4924
# regularly          2196
# trying to quit     1471
# Name: count, dtype: int64

# %% [markdown]
# ### Education
#
# 6,628 values missing

# %%
df['education'].value_counts()
# Out:
# education
# graduated from college/university    23816
# graduated from masters program        8901
# working on college/university         5672
# working on masters program            1674
# graduated from two-year college       1525
# graduated from high school            1413
# graduated from ph.d program           1264
# graduated from law school             1111
# working on two-year college           1063
# dropped out of college/university      993
# working on ph.d program                975
# college/university                     777
# graduated from space camp              651
# dropped out of space camp              515
# working on space camp                  443
# graduated from med school              443
# working on law school                  268
# two-year college                       220
# working on med school                  211
# dropped out of two-year college        191
# dropped out of masters program         140
# masters program                        133
# dropped out of ph.d program            126
# dropped out of high school              98
# high school                             95
# working on high school                  87
# space camp                              55
# ph.d program                            26
# law school                              19
# dropped out of law school               17
# dropped out of med school               12
# med school                               9
# Name: count, dtype: int64

# %%
# Define mapping for education levels
education_mapping = {
    'graduated from college/university': 'college/university_graduated',
    'working on college/university': 'college/university_studying',
    'dropped out of college/university': 'college/university_dropped out',
    'graduated from masters program': 'masters_graduated',
    'working on masters program': 'masters_studying',
    'dropped out of masters program': 'masters_dropped out',
    'graduated from ph.d program': 'ph.d_graduated',
    'working on ph.d program': 'ph.d_studying',
    'dropped out of ph.d program': 'ph.d_dropped out',
    'graduated from law school': 'law school_graduated',
    'working on law school': 'law school_studying',
    'dropped out of law school': 'law school_dropped out',
    'graduated from med school': 'med school_graduated',
    'working on med school': 'med school_studying',
    'dropped out of med school': 'med school_dropped out',
    'graduated from two-year college': 'two-year college_graduated',
    'working on two-year college': 'two-year college_studying',
    'dropped out of two-year college': 'two-year college_dropped out',
    'graduated from high school': 'high school_graduated',
    'working on high school': 'high school_studying',
    'dropped out of high school': 'high school_dropped out',
    'space camp': 'other',
    'working on space camp': 'other',
    'dropped out of space camp': 'other',
    'graduated from space camp': 'other'
}

# Apply the mapping
df['education'] = df['education'].map(education_mapping).fillna('unknown')

# Verify the result
print(df['education'].value_counts())
# Out:
# education
# college/university_graduated      23816
# masters_graduated                  8901
# unknown                            7158
# college/university_studying        5672
# masters_studying                   1674
# other                              1664
# two-year college_graduated         1525
# high school_graduated              1413
# ph.d_graduated                     1264
# law school_graduated               1111
# two-year college_studying          1063
# college/university_dropped out      993
# ph.d_studying                       975
# med school_graduated                443
# law school_studying                 268
# med school_studying                 211
# two-year college_dropped out        191
# masters_dropped out                 140
# ph.d_dropped out                    126
# high school_dropped out              98
# high school_studying                 87
# law school_dropped out               17
# med school_dropped out               12
# Name: count, dtype: int64

# %%
print(df['education'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ### Ethnicity

# %%
# checking the values
print(df['ethnicity'].value_counts())
# Out:
# ethnicity
# white                                              32495
# asian                                               6019
# hispanic / latin                                    2763
# black                                               1974
# other                                               1669
#                                                    ...
# black, native american, indian, white                  1
# black, native american, pacific islander, other        1
# asian, middle eastern, black, pacific islander         1
# middle eastern, black, pacific islander, white         1
# asian, black, indian                                   1
# Name: count, Length: 217, dtype: int64

# %% [markdown]
# Since there are over 217 different ethnicity combinations in this dataset, it's best to standardize the ethnicity column to reduce ambiguity.

# %%
def standardize_ethnicity(value):
    if pd.isna(value):  # if missing,
        return 'unknown'
    # Split by comma, strip whitespace, convert to lowercase, and remove duplicates
    ethnicities = sorted(set([eth.strip().lower() for eth in value.split(',')]))
    # Combine back into a standardized string
    return ', '.join(ethnicities)

# Apply the cleaning function to the 'ethnicity' column
df['ethnicity'] = df['ethnicity'].apply(standardize_ethnicity)

# Group rare combinations into a 'mixed' category (optional)
common_ethnicities = ['white', 'asian', 'black', 'hispanic / latin', 'native american', 'pacific islander', 'middle eastern']
df['ethnicity'] = df['ethnicity'].apply(
    lambda x: x if x in common_ethnicities else ('mixed' if ',' in x else x)
)

# Verify the cleaned and standardized column
print(df['ethnicity'].value_counts())
# Out:
# ethnicity
# white               32495
# mixed                6778
# asian                6019
# unknown              5262
# hispanic / latin     2763
# black                1974
# other                1669
# indian               1062
# pacific islander      413
# middle eastern        324
# native american        63
# Name: count, dtype: int64

# %% [markdown]
# ### Job

# %%
print(df['job'].value_counts())
# Out:
# job
# other                                7547
# student                              4851
# science / tech / engineering         4825
# computer / hardware / software       4682
# artistic / musical / writer          4410
# sales / marketing / biz dev          4373
# medicine / health                    3659
# education / academia                 3497
# executive / management               2357
# banking / financial / real estate    2240
# entertainment / media                2234
# law / legal services                 1369
# hospitality / travel                 1352
# construction / craftsmanship         1016
# clerical / administrative             801
# political / government                697
# rather not say                        431
# transportation                        363
# unemployed                            270
# retired                               246
# military                              201
# Name: count, dtype: int64

# %% [markdown]
# Although the job column is useful in its current form. The best thing to do is fill in the NaNs as 'rather not say'.

# %%
df['job'] = df['job'].fillna('rather not say')
print(df['job'].value_counts())
# Out:
# job
# rather not say                       7832
# other                                7547
# student                              4851
# science / tech / engineering         4825
# computer / hardware / software       4682
# artistic / musical / writer          4410
# sales / marketing / biz dev          4373
# medicine / health                    3659
# education / academia                 3497
# executive / management               2357
# banking / financial / real estate    2240
# entertainment / media                2234
# law / legal services                 1369
# hospitality / travel                 1352
# construction / craftsmanship         1016
# clerical / administrative             801
# political / government                697
# transportation                        363
# unemployed                            270
# retired                               246
# military                              201
# Name: count, dtype: int64

# %% [markdown]
# ### Location

# %%
df['location'].value_counts()
# Out:
# location
# san francisco, california    30514
# oakland, california           7107
# berkeley, california          4150
# san mateo, california         1309
# palo alto, california         1052
#                              ...
# jackson, mississippi             1
# ozone park, new york             1
# lake orion, michigan             1
# cambridge, massachusetts         1
# rochester, michigan              1
# Name: count, Length: 195, dtype: int64

# %% [markdown]
# We're not able to see all the locations, but we're going to go ahead and standardized.

# %%
df['location'] = df['location'].str.lower().str.strip()

# %% [markdown]
# ### Offspring

# %%
df['offspring'].value_counts()
# Out:
# offspring
# doesn't have kids                          7509
# doesn't have kids, but might want them     3859
# doesn't have kids, but wants them          3554
# doesn't want kids                          2909
# has kids                                   1874
# has a kid                                  1869
# doesn't have kids, and doesn't want any    1128
# has kids, but doesn't want more             440
# has a kid, but doesn't want more            274
# has a kid, and might want more              229
# wants kids                                  223
# might want kids                             181
# has kids, and might want more               113
# has a kid, and wants more                    71
# has kids, and wants more                     21
# Name: count, dtype: int64

# %%
offspring_mapping = {
    "doesn't have kids": "no kids, no preference",
    "doesn't have kids, but might want them": "no kids, might want",
    "doesn't have kids, but wants them": "no kids, wants",
    "doesn't want kids": "no kids, doesn't want",
    "has kids": "has kids, no preference",
    "has a kid": "has kids, no preference",
    "doesn't have kids, and doesn't want any": "no kids, doesn't want",
    "has kids, but doesn't want more": "has kids, doesn't want more",
    "has a kid, but doesn't want more": "has kids, doesn't want more",
    "has a kid, and might want more": "has kids, might want more",
    "wants kids": "wants kids",
    "might want kids": "might want kids",
    "has kids, and might want more": "has kids, might want more",
    "has a kid, and wants more": "has kids, wants more",
    "has kids, and wants more": "has kids, wants more"
}

df['offspring'] = df['offspring'].map(offspring_mapping).fillna('unknown')

# %%
df['offspring'].sample(15)
# Out:
# 23642             no kids, wants
# 45370        no Kids, might want
# 19824      no kids, doesn't want
# 5375         no Kids, might want
# 55932        no Kids, might want
# 20108                    unknown
# 30028                    unknown
# 40023    has kids, no preference
# 7106              no kids, wants
# 55875        no Kids, might want
# 7217      no kids, no preference
# 4349                     unknown
# 10693        no Kids, might want
# 12886     no kids, no preference
# 42220     no kids, no preference
# Name: offspring, dtype: object

# %% [markdown]
# ### Pets

# %%
df['pets'].value_counts()
# Out:
# pets
# likes dogs and likes cats          14753
# likes dogs                          7191
# likes dogs and has cats             4293
# has dogs                            4096
# has dogs and likes cats             2324
# likes dogs and dislikes cats        2022
# has dogs and has cats               1464
# has cats                            1395
# likes cats                          1057
# has dogs and dislikes cats           548
# dislikes dogs and likes cats         235
# dislikes dogs and dislikes cats      191
# dislikes cats                        122
# dislikes dogs and has cats            81
# dislikes dogs                         44
# Name: count, dtype: int64

# %%
pets_mapping = {
    "likes dogs and likes cats": "likes pets",
    "likes dogs": "likes dogs",
    "likes cats": "likes cats",
    "likes dogs and has cats": "has pets",
    "has dogs": "has pets",
    "has dogs and likes cats": "has pets",
    "has dogs and has cats": "has pets",
    "has cats": "has pets",
    "has dogs and dislikes cats": "has pets",
    "likes dogs and dislikes cats": "likes dogs",
    "dislikes dogs and likes cats": "likes cats",
    "dislikes dogs and dislikes cats": "dislikes pets",
    "dislikes cats": "dislikes pets",
    "dislikes dogs": "dislikes pets",
    "dislikes dogs and has cats": "has pets"
}

# Apply mapping directly to the 'pets' column
df['pets'] = df['pets'].map(pets_mapping).fillna("unknown")

# Verify changes
print(df['pets'].value_counts())
# Out:
# pets
# unknown          19006
# likes pets       14753
# has pets         14201
# likes dogs        9213
# likes cats        1292
# dislikes pets      357
# Name: count, dtype: int64

# %% [markdown]
# ### Religion

# %%
df['religion'].value_counts()
# Out:
# religion
# agnosticism                                   2701
# other                                         2671
# agnosticism but not too serious about it      2631
# agnosticism and laughing about it             2488
# catholicism but not too serious about it      2304
# atheism                                       2166
# other and laughing about it                   2108
# atheism and laughing about it                 2067
# christianity but not too serious about it     1945
# christianity                                  1939
# other but not too serious about it            1549
# judaism but not too serious about it          1512
# atheism but not too serious about it          1315
# catholicism                                   1054
# christianity and somewhat serious about it     922
# atheism and somewhat serious about it          848
# other and somewhat serious about it            839
# catholicism and laughing about it              724
# judaism and laughing about it                  677
# buddhism but not too serious about it          645
# agnosticism and somewhat serious about it      639
# judaism                                        605
# christianity and very serious about it         569
# atheism and very serious about it              568
# catholicism and somewhat serious about it      545
# other and very serious about it                525
# buddhism and laughing about it                 465
# buddhism                                       403
# christianity and laughing about it             373
# buddhism and somewhat serious about it         357
# agnosticism and very serious about it          313
# judaism and somewhat serious about it          264
# hinduism but not too serious about it          226
# hinduism                                       105
# catholicism and very serious about it           99
# buddhism and very serious about it              67
# hinduism and somewhat serious about it          57
# islam                                           47
# hinduism and laughing about it                  44
# islam but not too serious about it              40
# judaism and very serious about it               22
# islam and somewhat serious about it             21
# islam and laughing about it                     15
# hinduism and very serious about it              14
# islam and very serious about it                 12
# Name: count, dtype: int64

# %%
# Define a dictionary-based mapping for standardizing religion
religion_mapping = {
    "agnosticism": "agnosticism",
    "agnosticism but not too serious about it": "agnosticism",
    "agnosticism and laughing about it": "agnosticism",
    "agnosticism and somewhat serious about it": "agnosticism",
    "agnosticism and very serious about it": "agnosticism",
    "atheism": "atheism",
    "atheism but not too serious about it": "atheism",
    "atheism and laughing about it": "atheism",
    "atheism and somewhat serious about it": "atheism",
    "atheism and very serious about it": "atheism",
    "christianity": "christianity",
    "christianity but not too serious about it": "christianity",
    "christianity and laughing about it": "christianity",
    "christianity and somewhat serious about it": "christianity",
    "christianity and very serious about it": "christianity",
    "catholicism": "catholicism",
    "catholicism but not too serious about it": "catholicism",
    "catholicism and laughing about it": "catholicism",
    "catholicism and somewhat serious about it": "catholicism",
    "catholicism and very serious about it": "catholicism",
    "judaism": "judaism",
    "judaism but not too serious about it": "judaism",
    "judaism and laughing about it": "judaism",
    "judaism and somewhat serious about it": "judaism",
    "judaism and very serious about it": "judaism",
    "buddhism": "buddhism",
    "buddhism but not too serious about it": "buddhism",
    "buddhism and laughing about it": "buddhism",
    "buddhism and somewhat serious about it": "buddhism",
    "buddhism and very serious about it": "buddhism",
    "islam": "islam",
    "islam but not too serious about it": "islam",
    "islam and laughing about it": "islam",
    "islam and somewhat serious about it": "islam",
    "islam and very serious about it": "islam",
    "hinduism": "hinduism",
    "hinduism but not too serious about it": "hinduism",
    "hinduism and laughing about it": "hinduism",
    "hinduism and somewhat serious about it": "hinduism",
    "hinduism and very serious about it": "hinduism",
}

# Apply mapping directly to 'religion' column
df['religion'] = df['religion'].str.lower().map(religion_mapping).fillna("other")

# Verify results
print(df['religion'].value_counts())
# Out:
# religion
# other           27014
# agnosticism      8772
# atheism          6964
# christianity     5748
# catholicism      4726
# judaism          3080
# buddhism         1937
# hinduism          446
# islam             135
# Name: count, dtype: int64

# %% [markdown]
# ### Speaks Column

# %%
df['speaks'].value_counts()
# Out:
# speaks
# english                                                                  21016
# english (fluently)                                                        6583
# english (fluently), spanish (poorly)                                      2050
# english (fluently), spanish (okay)                                        1905
# english (fluently), spanish (fluently)                                    1275
#                                                                          ...
# english (fluently), french (okay), italian (okay), hebrew (okay)             1
# english (fluently), farsi (poorly), spanish (poorly), french (poorly)        1
# english (okay), tagalog (okay), japanese (poorly), french (poorly)           1
# english, spanish (fluently), lisp (okay)                                     1
# english (fluently), french, farsi                                            1
# Name: count, Length: 7596, dtype: int64

# %% [markdown]
# I want to standardize this column, but I wonder if standardizing will impact PCA results. I will preserve the original column, but create a new column that standardizes the 'speak' column to see if it has an impact on PCA. If not, I will drop the column.

# %%
df['speaks_original'] = df['speaks']

# %%
def categorize_speaks(speaks):
    if pd.isna(speaks):
        return "unknown"  # Handle missing values

    # Remove fluency descriptors (e.g., "(fluently)", "(okay)", "(poorly)")
    cleaned_languages = re.sub(r"\s?\(.*?\)", "", speaks)

    # Convert to lowercase and split into individual languages
    languages = set(cleaned_languages.lower().split(", "))

    # Classify as 'multilingual' if more than one language is listed
    return "monolingual" if len(languages) == 1 else "multilingual"

# Apply function directly to the 'speaks' column
df['speaks'] = df['speaks_original'].apply(categorize_speaks)

# %%
df['speaks'].value_counts()
# Out:
# speaks
# multilingual    30348
# monolingual     28433
# unknown            41
# Name: count, dtype: int64

# %%
df[['speaks_original','speaks']].sample(5)
# Out:
#                                          speaks_original        speaks
# 43778  english (fluently), spanish (fluently), japane...  multilingual
# 22779  english (fluently), hungarian (fluently), span...  multilingual
# 47788                                            english   monolingual
# 23823  english (fluently), spanish (poorly), yiddish ...  multilingual
# 23998                                 english (fluently)   monolingual

# %% [markdown]
# For some reason, the speaks_original column contains non-human languages such as C++. Let's remove it.

# %%
programming_languages = {"c++", "java", "python", "javascript", "html", "css", "ruby", "swift", "php", "r", "sql"}

def clean_speaks(text):
    if pd.isna(text):
        return text  # Keep NaNs as they are

    words = re.split(r',\s*', str(text).lower())  # Split by commas and clean spaces
    cleaned_words = []

    for word in words:
        # Remove proficiency labels
        word = re.sub(r"\(.*?\)", "", word).strip()

        # Exclude programming languages
        if word not in programming_languages and word.isalpha():
            cleaned_words.append(word)

    return ", ".join(cleaned_words) if cleaned_words else None  # Return cleaned list or None if empty

# Apply the cleaning function to the speaks_original column
df['speaks_original'] = df['speaks_original'].apply(clean_speaks)

# %%
df[['speaks_original','speaks']].sample(5)
# Out:
#         speaks_original        speaks
# 40124           english   monolingual
# 12243  english, spanish  multilingual
# 56309           english   monolingual
# 54165           english   monolingual
# 25234           english   monolingual

# %% [markdown]
# ##4.3 Cleaning Essay Columns

# %%
df['combined_essay_cols'] = df[
    ['essay0', 'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']
].fillna("").apply(lambda x: " ".join(x), axis=1)

# %%
df.drop(columns=['essay0', 'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9'], inplace=True)

# %%
df['combined_essay_cols'].sample()
# Out:
# 1063    i was born here in san francisco, but was rais...
# Name: combined_essay_cols, dtype: object

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
spell = SpellChecker()

def preprocess_text(text):
  text = text.lower()
  text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation
  tokens = text.split()  # Faster alternative: text.split()
  return tokens

def remove_stopwords(tokens):
  return [word for word in tokens if word not in stop_words]

def remove_long_words(tokens, max_length=20):
  return [word for word in tokens if len(word) <= max_length]

def lemmatization(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

# %%
def clean_text(text):
  if not isinstance(text, str) or text.strip() =="":  # Ensure text is a string, handle NaNs
        return ""

  tokens = preprocess_text(text)
  tokens = remove_stopwords(tokens)
  tokens = remove_long_words(tokens)  # Removes words > 20 characters
  tokens = lemmatization(tokens)
  return " ".join(tokens)  # Convert back to string for TF-IDF


df['cleaned_essays'] = df['combined_essay_cols'].astype(str).swifter.apply(clean_text)
# Out:
# Pandas Apply:   0%|          | 0/58822 [00:00<?, ?it/s]

# %%
df['speaks_original'].sample(10)
# Out:
# 29632     english, hebrew
# 8466              english
# 39772             english
# 36858             english
# 51084             english
# 51380             english
# 12806             english
# 19711             english
# 6968              english
# 5445     english, english
# Name: speaks_original, dtype: object

# %%
df.sample(10)
# Out:
#        age          status sex orientation        diet             drinks  \
# 21296   42  seeing someone   m    straight     unknown           socially
# 20187   45          single   m         gay     unknown           socially
# 59528   22          single   m    straight     unknown  rarely/not at all
# 5023    19          single   m    straight    anything           socially
# 50975   25          single   f    straight  vegetarian  rarely/not at all
# 32104   32          single   f    straight     unknown           socially
# 19886   43          single   f    straight    anything           socially
# 46941   33          single   f    straight    anything           socially
# 25358   30          single   m    straight     unknown           socially
# 12118   59          single   f    bisexual     unknown  rarely/not at all
#
#        drugs                     education         ethnicity  height  \
# 21296  never  college/university_graduated             white    67.0
# 20187  never             masters_graduated             asian    66.0
# 59528  never         high school_graduated  hispanic / latin    66.0
# 5023   never         high school_graduated             asian    72.0
# 50975  never             masters_graduated             mixed    68.0
# 32104  never  college/university_graduated             asian    67.0
# 19886  never  college/university_graduated             other    60.0
# 46941  never                       unknown           unknown    62.0
# 25358  never  college/university_graduated           unknown    69.0
# 12118  never    two-year college_graduated             white    64.0
#
#                                      job                   location  \
# 21296             executive / management  san francisco, california
# 20187        artistic / musical / writer    mill valley, california
# 59528       construction / craftsmanship        oakland, california
# 5023                             student        oakland, california
# 50975               education / academia  san francisco, california
# 32104              entertainment / media  san francisco, california
# 19886  banking / financial / real estate        oakland, california
# 46941        sales / marketing / biz dev  san francisco, california
# 25358             political / government       berkeley, california
# 12118       construction / craftsmanship        oakland, california
#
#                     offspring      pets     religion        smokes  \
# 21296                 unknown   unknown  agnosticism            no
# 20187                 unknown   unknown        other            no
# 59528                 unknown  has pets        other            no
# 5023                  unknown   unknown  agnosticism            no
# 50975                 unknown  has pets        other            no
# 32104                 unknown   unknown        other            no
# 19886  no kids, no preference  has pets  catholicism  occasionally
# 46941  no kids, no preference   unknown        other            no
# 25358          no kids, wants  has pets  catholicism            no
# 12118                 unknown  has pets        other            no
#
#              speaks                      speaks_original  \
# 21296  multilingual                      english, french
# 20187  multilingual  english, french, spanish, norwegian
# 59528  multilingual                     english, spanish
# 5023   multilingual                     english, chinese
# 50975  multilingual               english, farsi, french
# 32104   monolingual                              english
# 19886  multilingual            english, tagalog, spanish
# 46941  multilingual                  english, indonesian
# 25358   monolingual                              english
# 12118   monolingual                              english
#
#                                      combined_essay_cols  \
# 21296  like a lot of people i meet in sf, i'm a trans...
# 20187  i teach, i write, i travel. i have a passion f...
# 59528  i'm sporty i play guitar i love music trying t...
# 5023   i am asian i am 6 feet tall, i'm into cars, an...
# 50975  inquisitive. sensitive. loquacious teaching ea...
# 32104  i love the arts and music and travel are a big...
# 19886  "attitude is a little thing that makes a big d...
# 46941  hello! to start, i am from indonesia and have ...
# 25358    singing marvin gaye and elton john songs at ...
# 12118   12 step recovery, spiritual work/retreats lis...
#
#                                           cleaned_essays
# 21296  like lot people meet sf im transplant grew bac...
# 20187  teach write travel passion three thing ive for...
# 59528  im sporty play guitar love music trying join p...
# 5023   asian 6 foot tall im car shoe preferably jorda...
# 50975  inquisitive sensitive loquacious teaching eage...
# 32104  love art music travel big part life working di...
# 19886  attitude little thing make big difference wins...
# 46941  hello start indonesia calling bay home almost ...
# 25358  singing marvin gaye elton john song karaoke ba...
# 12118  12 step recovery spiritual workretreats listen...

# %% [markdown]
# ### Final Dataframe

# %%
df.to_csv('df_cleaned.csv', index=False)

# %%
# # Load model from HuggingFace Hub
# tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
# model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# def bert_embeddings(text):

#   def mean_pooling(model_output, attention_mask):
#     token_embeddings = model_output[0] #First element of model_output contains all token embeddings
#     input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
#     return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

#   encoded_input = tokenizer(text, padding=True, truncation=True, return_tensors='pt')

#   # Compute token embeddings
#   with torch.no_grad():
#     model_output = model(**encoded_input)

#   # Perform pooling
#   essay_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

#   # Normalize embeddings
#   essay_embeddings = F.normalize(essay_embeddings, p=2, dim=1)
#   normalized_essay = np.array(essay_embeddings)
#   return

# %%
# from transformers import AutoTokenizer, AutoModel
# import torch
# import torch.nn.functional as F

# #Mean Pooling - Take attention mask into account for correct averaging
# def mean_pooling(model_output, attention_mask):
#     token_embeddings = model_output[0] #First element of model_output contains all token embeddings
#     input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
#     return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# # Sentences we want sentence embeddings for
# sentences = ['This is an example sentence', 'Each sentence is converted']

# # Load model from HuggingFace Hub
# tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
# model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# # Tokenize sentences
# encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# # Compute token embeddings
# with torch.no_grad():
#     model_output = model(**encoded_input)

# # Perform pooling
# sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# # Normalize embeddings
# sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

# print("Sentence embeddings:")
# print(sentence_embeddings)
